# %%
import pandas as pd

# %% [markdown]
# En primer lugar, antes de realizar las pruebas para obtener diferentes endpoints (funciones) para el sistema de recomendación, cabe aclarar que se utilizará un sistema de puntuación ponderada, en el que se tenga en cuenta el número de reseñas, además de su promedio de calificaciones.

# %%
# Definir la función para calcular la puntuación ponderada
def weighted_rating(df, m, C):
    v = df['num_of_reviews']  # Número de reseñas
    R = df['avg_rating']      # Calificación promedio
    # Fórmula para calcular el Weighted Rating
    return (v/(v+m)) * R + (m/(m+v)) * C

# %%
# Filtrar restaurantes por categoría y ciudad
def recomendar_restaurantes_por_sabor(df, tipo_comida, ciudad):
    # Filtrar por tipo de comida y ciudad
    df_filtrado = df[(df['category'].str.contains(tipo_comida, case=False)) & (df['city'] == ciudad)].copy()
    
    # Calcular puntuación ponderada para cada restaurante
    m = df_filtrado['num_of_reviews'].quantile(0.90)  # Umbral para el número mínimo de reseñas
    C = df_filtrado['avg_rating'].mean()  # Calificación promedio de todos los restaurantes
    df_filtrado.loc[:, 'puntuacion'] = weighted_rating(df_filtrado, m, C)  # Usar .loc para evitar el warning
    
    # Ordenar por puntuación
    df_top5 = df_filtrado.sort_values('puntuacion', ascending=False).head(5)
    
    return df_top5[['name', 'category', 'avg_rating', 'num_of_reviews', 'address_depurada','city']]

# %%
# Ejemplo de uso
df = pd.read_parquet(r'C:\Users\GASTON\Desktop\PROYECTO FINAL\DATA\locales_google.parquet')  # Cargar la tabla de negocios
top_restaurantes = recomendar_restaurantes_por_sabor(df, 'Pizza', 'San Francisco')
print(top_restaurantes)
# Out:
#                                             name  \
# 2594792                   Presidio Pizza Company
# 1335286                           Monza Pizzeria
# 2444761                   Valencia Pizza & Pasta
# 2002146  Tricolore Caffè & Pizzeria and Catering
# 1361621                          That's Amore SF
#
#                                                   category  avg_rating  \
# 2594792                       Pizza restaurant, Restaurant         4.3
# 1335286                                   Pizza restaurant         4.6
# 2444761  Italian restaurant, Breakfast restaurant, Pizz...         4.3
# 2002146  Italian restaurant, Bagel shop, Cafe, Catering...         4.5
# 1361621                                   Pizza restaurant         4.8
#
#          num_of_reviews           city
# 2594792             228  San Francisco
# 1335286              78  San Francisco
# 2444761             178  San Francisco
# 2002146              78  San Francisco
# 1361621              35  San Francisco

# %%
prueba2 = recomendar_restaurantes_por_sabor(df, 'Burger', 'Santa Barbara')
prueba2
# Out:
#                     name                                           category  \
# 2621702  Jack in the Box  Fast food restaurant, Breakfast restaurant, Ch...
#
#          avg_rating  num_of_reviews           city
# 2621702         3.7             518  Santa Barbara

# %%
prueba3= recomendar_restaurantes_por_sabor(df, 'coffee', 'Los Angeles')
prueba3
# Out:
#                                name  \
# 2547300                Philz Coffee
# 2387742       Verve Coffee Roasters
# 2543080  Tiago Coffee Bar + Kitchen
# 2522477            Coffee Del Mundo
# 2491709  Aquarela by SPLA Coffee Co
#
#                                                   category  avg_rating  \
# 2547300                                        Coffee shop         4.6
# 2387742                                        Coffee shop         4.5
# 2543080  Coffee shop, Breakfast restaurant, Brunch rest...         4.5
# 2522477                       Coffee roasters, Coffee shop         4.8
# 2491709                                        Coffee shop         4.7
#
#          num_of_reviews     address_depurada         city
# 2547300             478     6430 Sunset Blvd  Los Angeles
# 2387742             848      833 S Spring St  Los Angeles
# 2543080             628  7080 Hollywood Blvd  Los Angeles
# 2522477              77   7414 S Vermont Ave  Los Angeles
# 2491709              86    714 N Figueroa St  Los Angeles

# %% [markdown]
# Estas primeras pruebas me dan la pauta de que puedo hacer diferentes consultas para mis recomendaciones, basadas en los datasets disponibles.

# %% [markdown]
# # Creación sistema de recomendación

# %% [markdown]
# Realizada la observación anterior, elegimos cuáles serán las posibles consultas a realizarse, y se definen las siguientes:
# - Recomendar restaurantes basados en el tipo de comida y ciudad
# - Recomendación por Zona: ingreso determinada ciudad y me indicará los mejores locales gastronómicos.
# - Recomendar según palabras clave en las reseñas (busca sólo de acuerdo a comercios en que hayan dejado una descripción los usuarios)
# - Recomendar locales según reseñas similares

# %% [markdown]
# Para el último caso, necesitaremos reducir la muestra a aquellas reseñas que tengan comentarios de texto.

# %%
df_reviews = pd.read_parquet(r'C:\Users\GASTON\Desktop\PROYECTO FINAL\DATA\reviews_google.parquet')
df_reviews.head(3)
# Out:
#    review_id       user_id         name       time  rating  \
# 0          1  1.089912e+20      Song Ro 2021-06-01       5
# 1          2  1.112903e+20  Rafa Robles 2021-09-02       5
# 2          3  1.126404e+20    David Han 2020-08-03       4
#
#                                                text  \
# 0                      Love there korean rice cake.
# 1                                    Good very good
# 2  They make Korean traditional food very properly.
#
#                                  gmap_id
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49

# %%
df_reseñas_muestra = df_reviews[df_reviews['text'] != 'Sin Reseña']
df_reseñas_muestra.head(3)
# Out:
#    review_id       user_id         name       time  rating  \
# 0          1  1.089912e+20      Song Ro 2021-06-01       5
# 1          2  1.112903e+20  Rafa Robles 2021-09-02       5
# 2          3  1.126404e+20    David Han 2020-08-03       4
#
#                                                text  \
# 0                      Love there korean rice cake.
# 1                                    Good very good
# 2  They make Korean traditional food very properly.
#
#                                  gmap_id
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49

# %%
df_reseñas_muestra.to_parquet(r'C:\Users\GASTON\Desktop\PROYECTO FINAL\DATA\reseñas_ml.parquet')

# %% [markdown]
# Lo extramos en formato parquet para utilizar directamente en el archivo .py

# %%
df = pd.read_parquet(r'C:\Users\GASTON\Desktop\PROYECTO FINAL\DATA\reseñas_ml.parquet')

# %% [markdown]
# Comenzamos con la creación de los diferentes endpoints del modelo

# %%
# Importar las librerías necesarias
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Cargar el archivo de datos (ajusta la ruta a tu archivo)
df_business = pd.read_parquet(r'C:\Users\GASTON\Desktop\PROYECTO FINAL\DATA\locales_google.parquet')  # Tabla de negocios
df_reviews = pd.read_parquet(r'C:\Users\GASTON\Desktop\PROYECTO FINAL\DATA\reseñas_ml.parquet')  # Tabla de reseñas con datos en 'text'

# Mostrar las primeras filas para asegurarnos de que los datos estén cargados correctamente
df_reviews.head()
# Out:
#     review_id       user_id         name       time  rating  \
# 0           1  1.089912e+20      Song Ro 2021-06-01       5
# 1           2  1.112903e+20  Rafa Robles 2021-09-02       5
# 2           3  1.126404e+20    David Han 2020-08-03       4
# 3           4  1.174403e+20  Anthony Kim 2019-07-03       5
# 25          8  1.035179e+20    andee tea 2021-02-09       5
#
#                                                  text  \
# 0                        Love there korean rice cake.
# 1                                      Good very good
# 2    They make Korean traditional food very properly.
# 3                      Short ribs are very delicious.
# 25  Love this place  fried garlic chicken was very...
#
#                                   gmap_id
# 0   0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1   0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2   0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3   0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 25  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42

# %% [markdown]
# Probaremos la función para recomendar restaurantes por sabor y ciudad

# %%
#Primero definimos las funciones

def weighted_rating(x, m, C):
    v = x['num_of_reviews']
    R = x['avg_rating']
    return (v / (v + m) * R) + (m / (v + m) * C)

def recomendar_restaurantes_por_sabor(df, tipo_comida, ciudad):
    # Filtrar por tipo de comida y ciudad
    df_filtrado = df[(df['category'].str.contains(tipo_comida, case=False, na=False)) & (df['city'] == ciudad)]
    
    # Verificar si hay registros
    if df_filtrado.empty:
        return f"No se encontraron restaurantes de {tipo_comida} en {ciudad}."
    
    # Calcular los parámetros para la puntuación ponderada
    m = df_filtrado['num_of_reviews'].quantile(0.90)
    C = df_filtrado['avg_rating'].mean()
    
    # Aplicar la puntuación ponderada
    df_filtrado['puntuacion'] = df_filtrado.apply(lambda x: weighted_rating(x, m, C), axis=1)
    
    # Ordenar y devolver el top 5
    df_top5 = df_filtrado.sort_values('puntuacion', ascending=False).head(5)
    return df_top5[['name', 'avg_rating', 'num_of_reviews', 'city', 'category']]

# %%
# Probar la función #1
top_restaurantes = recomendar_restaurantes_por_sabor(df_business, 'Pizza', 'San Francisco')
top_restaurantes
# Out:
# C:\Users\GASTON\AppData\Local\Temp\ipykernel_17104\3594798651.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['puntuacion'] = df_filtrado.apply(lambda x: weighted_rating(x, m, C), axis=1)
#                                             name  avg_rating  num_of_reviews  \
# 2594792                   Presidio Pizza Company         4.3             228
# 1335286                           Monza Pizzeria         4.6              78
# 2444761                   Valencia Pizza & Pasta         4.3             178
# 2002146  Tricolore Caffè & Pizzeria and Catering         4.5              78
# 1361621                          That's Amore SF         4.8              35
#
#                   city                                           category
# 2594792  San Francisco                       Pizza restaurant, Restaurant
# 1335286  San Francisco                                   Pizza restaurant
# 2444761  San Francisco  Italian restaurant, Breakfast restaurant, Pizz...
# 2002146  San Francisco  Italian restaurant, Bagel shop, Cafe, Catering...
# 1361621  San Francisco                                   Pizza restaurant

# %% [markdown]
# Efectivamente, esta función tiene buenos resultados, pero arroja un warning. De todas formas, se mejorará luego de analizar todas las opciones.

# %% [markdown]
# *Ahora continamos con la función para buscar restaurantes en una zona*

# %%
def recomendar_restaurantes_por_zona(df, ciudad):
    # Filtrar por ciudad
    df_filtrado = df[df['city'] == ciudad]
    
    if df_filtrado.empty:
        return f"No se encontraron restaurantes en {ciudad}."
    
    # Ordenar por rating promedio y devolver el top 5
    df_top5 = df_filtrado.sort_values('avg_rating', ascending=False).head(5)
    return df_top5[['name', 'avg_rating', 'num_of_reviews', 'category']]

# %%
# Probar la función
top_zona = recomendar_restaurantes_por_zona(df_business, 'San Francisco')
top_zona
# Out:
#                         name  avg_rating  num_of_reviews  \
# 2498158             Serafina         5.0              48
# 1956301  Ham and Cheese Deli         5.0              26
# 1642943             Pho 2000         5.0              18
# 2209316               Ernest         4.9              28
# 2554745         Paula's Cafe         4.9              35
#
#                                                   category
# 2498158                                         Restaurant
# 1956301                                         Restaurant
# 1642943                              Vietnamese restaurant
# 2209316                                         Restaurant
# 2554745  Bar & grill, Breakfast restaurant, Brunch rest...

# %% [markdown]
# Busca correctamente las reseñas, pero no tiene los metadatos para ofrecer la información del comercio.

# %% [markdown]
# *Continuamos con la búsqueda de palabras clave en las reseñas*

# %%
def buscar_palabras_clave(df_reviews, palabras_clave):
    # Unir las palabras clave en una expresión regular
    palabras_regex = '|'.join([f'\\b{palabra}\\b' for palabra in palabras_clave])
    
    # Filtrar las reseñas que contienen las palabras clave
    df_filtrado = df_reviews[df_reviews['text'].str.contains(palabras_regex, case=False, na=False)]
    
    if df_filtrado.empty:
        return "No se encontraron reseñas con las palabras clave."
    
    # Devolver algunas columnas importantes de las reseñas
    return df_filtrado[['review_id', 'name', 'rating', 'text']].head(10)

# %%
# Probar la función
palabras_clave = ['amazing', 'good', 'friendly']
resenas_filtradas = buscar_palabras_clave(df_reviews, palabras_clave)
resenas_filtradas
# Out:
#       review_id             name  rating  \
# 1             2      Rafa Robles       5
# 27           10     Soongil Choe       5
# 743          15         john b89       5
# 1379         29    rick belfiore       4
# 1751         34         Don Cote       5
# 1754         36  Maritza Cornejo       5
# 1757         39           Crys P       5
# 2269         42      Dylan Simon       5
# 2272         44   Scott Zawalski       4
# 2276         46        Hung Pham       3
#
#                                                    text
# 1                                        Good very good
# 27    (Translated by Google) There is a different me...
# 743   It's circle k, cigs,coffee munchies, they got ...
# 1379                                       Good hot dog
# 1751        Great food. Friendly and efficient service!
# 1754                       Good take out food as always
# 1757                            Everything was so good!
# 2269  Hotei is the best Japanese restaurant in the c...
# 2272  Good ramen and tasty Sushi. I wouldn't go here...
# 2276  it's a good place to go on monday's when ebisu...

# %%
# Probar la función
palabras_clave = ['good burger']
resenas_filtradas = buscar_palabras_clave(df_reviews, palabras_clave)
resenas_filtradas
# Out:
#         review_id              name  rating  \
# 79823        1620        Nicole Hsu       2
# 128189       3244     Rick Bolander       3
# 194384      10672       Bodied_alex       1
# 245387      16710  Stephanie Hughes       5
# 245698      16814       Mark Herwig       4
# 269039      19431    Phillip Chacon       4
# 269177      19479           Rob Roy       5
# 269208      19489         Jovany D.       4
# 269273      19513       Seth Warner       5
# 269282      19515        Eric Jay H       4
#
#                                                      text
# 79823   My bf and I love a good burger. Umai has a pre...
# 128189                             Pricey but good burger
# 194384  Over priced frozen burger patty not the beezne...
# 245387  My husband and I are new to the area and wante...
# 245698            Pretty good burger place, not expensive
# 269039  Good burger, you can tell in the taste that ev...
# 269177  A consistently good burger with grass fed beef...
# 269208  Really good burger. Shakes are great. Pretty p...
# 269273         Extremely friendly service and good burger
# 269282   Pretty damn good burger. A bit too spendy for me

# %% [markdown]
# La búsqueda de las palabras es apropiada, pero una vez más, no cuenta con los metadatos para traer información del comercio.

# %% [markdown]
# *Ahora generamos la recomendación de restaurantes por reseña:*

# %%
def recomendar_restaurantes_por_reseñas(df_reviews, df_business, nombre_restaurante, top_n=5):
    # Buscar el restaurante en la tabla de negocios (df_business)
    df_restaurante = df_business[df_business['name'].str.contains(nombre_restaurante, case=False, na=False)]
    
    if df_restaurante.empty:
        return f"No se encontraron restaurantes con el nombre {nombre_restaurante}."
    
    # Obtener el gmap_id del primer restaurante encontrado (asumiendo que es único)
    gmap_id = df_restaurante.iloc[0]['gmap_id']
    
    # Filtrar las reseñas que tienen texto y corresponden a este restaurante
    df_filtrado = df_reviews[(df_reviews['text'].notnull()) & (df_reviews['gmap_id'] == gmap_id)]
    
    if df_filtrado.empty:
        return f"No se encontraron reseñas para el restaurante {nombre_restaurante}."
    
    # Resetear el índice del DataFrame filtrado para evitar problemas con el índice
    df_filtrado = df_filtrado.reset_index(drop=True)
    
    # Crear la matriz TF-IDF
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(df_filtrado['text'])
    
    # Calcular la similitud del coseno entre todas las reseñas
    cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
    
    # Obtener el índice del restaurante en la matriz
    idx = 0  # Siempre usamos el primer índice ya que reiniciamos el DataFrame
    
    # Verificar que la matriz de similitud tiene el tamaño correcto
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Ordenar por similitud y devolver los más similares
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n + 1]
    
    # Obtener los índices de las reseñas recomendadas
    review_indices = [i[0] for i in sim_scores]
    
    return df_filtrado.iloc[review_indices][['name', 'rating', 'text']]

# %%
# Probar la función
recomendaciones = recomendar_restaurantes_por_reseñas(df_reviews, df_business, 'Pizza Hut')
recomendaciones
# Out:
#             name  rating                                               text
# 3    Les Schlais       4                                               Good
# 1  Cody Buchanan       5  There's a guy named Vlad who works there. He's...
# 2    Saul Zepeda       5                   Always fresh employees are great

# %% [markdown]
# Esta función es insuficiente, ya que cuando busco el nombre de un comercio, me trae reseñas del mismo comercio.

# %% [markdown]
# # Conclusiones: deben reformularse funciones y trabajar con otros datos
#
# De acuerdo a lo visto, debemos hacer un nuevo dataframe base unificando los campos a través del valor 'gmap_id' para poder obtener, a partir de las reseñas, recomendaciones de los restaurantes (y no de las reseñas propiamente dichas)

# %% [markdown]
# **Creación de DataFrame unificado**

# %%
# Seleccionar solo las columnas necesarias de df_business
df_business_filtrado = df_business[['gmap_id', 'name', 'address', 'category', 'avg_rating', 'num_of_reviews', 'city']]

# Seleccionar solo las columnas necesarias de df_reviews
df_reviews_filtrado = df_reviews[['gmap_id', 'rating', 'text']]

# Hacer el merge utilizando 'gmap_id' como clave
df_unificado = pd.merge(df_reviews_filtrado, df_business_filtrado, on='gmap_id', how='inner')

# Mostrar las primeras filas para verificar el resultado
df_unificado.head()
# Out:
#                                  gmap_id  rating  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49       5
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49       5
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49       4
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49       5
# 4  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42       5
#
#                                                 text          name  \
# 0                       Love there korean rice cake.  San Soo Dang
# 1                                     Good very good  San Soo Dang
# 2   They make Korean traditional food very properly.  San Soo Dang
# 3                     Short ribs are very delicious.  San Soo Dang
# 4  Love this place  fried garlic chicken was very...  Vons Chicken
#
#                                              address           category  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  Korean restaurant
# 1  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  Korean restaurant
# 2  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  Korean restaurant
# 3  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  Korean restaurant
# 4  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...         Restaurant
#
#    avg_rating  num_of_reviews         city
# 0         4.4              18  Los Angeles
# 1         4.4              18  Los Angeles
# 2         4.4              18  Los Angeles
# 3         4.4              18  Los Angeles
# 4         4.5              18    La Mirada

# %%
# Crear una columna combinada 'category_text' con la categoría repetida 3 veces para darle mayor peso
df_unificado['category_text'] = df_unificado['category'] + ' ' + df_unificado['category'] + ' ' + df_unificado['category'] + ' ' + df_unificado['text']

# %% [markdown]
# Esta nueva columna será utilizada para una de las funciones, que trabajan buscando coincidencias a través de TF-IDF (Term frequency – Inverse document frequency).

# %%
df_unificado.to_parquet(r'C:\Users\GASTON\Desktop\PROYECTO FINAL\DATA\ml_unificado.parquet')

# %% [markdown]
# **Volvemos a formular el primer endpoint del sistema de recomendación**

# %% [markdown]
# Recordemos que el siguiente sistema de recomendación utiliza la puntuación ponderada, según cantidad de reseñas y sus calificaciones

# %%
def recomendar_restaurantes_por_sabor_unificado(df, tipo_comida, ciudad, top_n=5):
    '''
    Esta función recibe un DataFrame sobre el que trabaja, el tipo de comida y la ciudad que se busca.
    Devuelve una recomendación de los locales con mejor puntuación ponderada que coincidan con esos criterios.
    '''
    # Filtrar por tipo de comida y ciudad
    df_filtrado = df[(df['category'].str.contains(tipo_comida, case=False, na=False)) & 
                     (df['city'].str.contains(ciudad, case=False, na=False))]
    
    if df_filtrado.empty:
        return f"No se encontraron restaurantes de {tipo_comida} en {ciudad}."
    
    # Agrupar por gmap_id para evitar duplicados
    df_agrupado = df_filtrado.groupby('gmap_id').agg({
        'name': 'first',  # Mantener el primer nombre del restaurante
        'address': 'first',  # Mantener la primera dirección del restaurante
        'category': 'first',  # Mantener la primera categoría
        'avg_rating': 'mean',  # Calcular el promedio de las calificaciones
        'num_of_reviews': 'sum',  # Sumar todas las reseñas
        'rating': 'mean'  # Calcular el promedio de las calificaciones de las reseñas
    }).reset_index()

    # Calcular la puntuación ponderada
    m = df_agrupado['num_of_reviews'].quantile(0.90)
    C = df_agrupado['avg_rating'].mean()
    df_agrupado['puntuacion'] = weighted_rating(df_agrupado, m, C)
    
    # Ordenar por puntuación
    df_top5 = df_agrupado.sort_values('puntuacion', ascending=False).head(top_n)
    
    # Seleccionar las columnas relevantes para mostrar
    return df_top5[['name', 'address', 'category', 'avg_rating', 'num_of_reviews', 'puntuacion']]

# %%
# Probar la función con el DataFrame unificado
recomendaciones_sabor = recomendar_restaurantes_por_sabor_unificado(df_unificado, 'Pizza', 'San Francisco')
recomendaciones_sabor
# Out:
#                                        name  \
# 2                    Presidio Pizza Company
# 10                   Valencia Pizza & Pasta
# 8                            Monza Pizzeria
# 1   Tricolore Caffè & Pizzeria and Catering
# 5                           That's Amore SF
#
#                                               address  \
# 2   Presidio Pizza Company, 1862 Divisadero St, Sa...
# 10  Valencia Pizza & Pasta, 801 Valencia St, San F...
# 8   Monza Pizzeria, 1934 Ocean Ave, San Francisco,...
# 1   Tricolore Caffè & Pizzeria and Catering, 590 W...
# 5   That's Amore SF, 1901 Ocean Ave, San Francisco...
#
#                                              category  avg_rating  \
# 2                        Pizza restaurant, Restaurant         4.3
# 10  Italian restaurant, Breakfast restaurant, Pizz...         4.3
# 8                                    Pizza restaurant         4.6
# 1   Italian restaurant, Bagel shop, Cafe, Catering...         4.5
# 5                                    Pizza restaurant         4.8
#
#     num_of_reviews  puntuacion
# 2             7752    4.116361
# 10            6764    4.102510
# 8              858    3.976151
# 1              858    3.964224
# 5              175    3.916082

# %% [markdown]
# Aquí podemos observar cómo el sistema de puntuación ponderada prevalece sobre el promedio de reseñas: si bien 'Monza Pizzeria' tiene una calificación promedio más alta, tiene una cantidad considerablemente menor de reseñas, por lo que se agrupan de acuerdo a la puntuación ponderada.
# Sin embargo, se indica el promedio de calificaciones para que el usuario pueda tenerlo en consideración.

# %%
# Probar la función con el DataFrame unificado
recomendaciones_sabor = recomendar_restaurantes_por_sabor_unificado(df_unificado, 'Burger', 'San Diego')
recomendaciones_sabor
# Out:
#                    name                                            address  \
# 8         Crazee Burger  Crazee Burger, 3993 30th St, San Diego, CA 921...
# 7          Veggie Grill  Veggie Grill, 4353 La Jolla Village Drive #H28...
# 4  Brooklyn Bar & Grill  Brooklyn Bar & Grill, 4727 University Ave, San...
# 0        Fatso's Bunker  Fatso's Bunker, 688 Hollister St ste b, San Di...
# 6  The Butcher N Cheese  The Butcher N Cheese, 4705 Clairemont Dr C, Sa...
#
#                                             category  avg_rating  \
# 8                               Hamburger restaurant         4.6
# 7  Vegan restaurant, Gluten-free restaurant, Hamb...         4.5
# 4  Bar & grill, American restaurant, Bar, Hamburg...         4.7
# 0                               Hamburger restaurant         4.8
# 6                               Hamburger restaurant         4.6
#
#    num_of_reviews  puntuacion
# 8          386384    4.515443
# 7           24208    4.358406
# 4            3072    4.345842
# 0            1170    4.342872
# 6            1020    4.341416

# %% [markdown]
# **Mejoramos función para buscar locales por zona**

# %%
def recomendar_restaurantes_por_zona(df, ciudad, top_n=5, min_reviews=10):
    '''
    Esta función recibe un DataFrame, y una ciudad o zona del Estado de California.
    Devuelve un top 10 de los mejores locales según la calificación ponderada.
    Pueden no haber reseñas suficientes en la ciudad o zona seleccionada.
    '''
    # Filtrar por ciudad
    df_filtrado = df[df['city'].str.contains(ciudad, case=False, na=False)]
    
    if df_filtrado.empty:
        return f"No se encontraron restaurantes en {ciudad}."
    
    # Filtrar solo restaurantes con un mínimo de reseñas
    df_filtrado = df_filtrado[df_filtrado['num_of_reviews'] >= min_reviews]
    
    if df_filtrado.empty:
        return f"No se encontraron restaurantes con al menos {min_reviews} reseñas en {ciudad}."
    
    # Ordenar por calificación promedio y número de reseñas
    df_top5 = df_filtrado.sort_values(['avg_rating', 'num_of_reviews'], ascending=[False, False]).head(top_n)
    
    # Seleccionar las columnas relevantes para mostrar
    return df_top5[['name', 'avg_rating', 'num_of_reviews', 'category', 'address']]

# %%
# Probar la función con el DataFrame df_business
recomendaciones_zona = recomendar_restaurantes_por_zona(df_business, 'San Francisco', top_n=5, min_reviews=20)
recomendaciones_zona
# Out:
#                         name  avg_rating  num_of_reviews  \
# 2498158             Serafina         5.0              48
# 1956301  Ham and Cheese Deli         5.0              26
# 2529977      Cheese Boutique         4.9              68
# 955338          Chic n’ Time         4.9              38
# 73188                   SPRO         4.9              35
#
#                                                   category  \
# 2498158                                         Restaurant
# 1956301                                         Restaurant
# 2529977  Cheese shop, Gourmet grocery store, Sandwich shop
# 955338                 Asian fusion restaurant, Restaurant
# 73188    Cafe, Bakery, Coffee shop, Dessert shop, Hambu...
#
#                                                    address
# 2498158   Serafina, 1701 Jones St, San Francisco, CA 94109
# 1956301  Ham and Cheese Deli, 5501 California St, San F...
# 2529977  Cheese Boutique, 660 Chenery St, San Francisco...
# 955338   Chic n’ Time, 807 Valencia St, San Francisco, ...
# 73188         SPRO, 500 Church St, San Francisco, CA 94114

# %%
# Probar la función con el DataFrame df_business
recomendaciones_zona = recomendar_restaurantes_por_zona(df_business, 'Los Angeles', top_n=5, min_reviews=20)
recomendaciones_zona
# Out:
#                                                       name  avg_rating  \
# 2504391                                    Juanito's Tacos         4.9
# 1422509                                             Eszett         4.9
# 1460247                                       Cafe De Mama         4.9
# 1817065  50/50 Juice Lounge, Where Health Meets Juice 4...         4.9
# 2588766           Mo's House Of Axe * Temporarily Closed *         4.9
#
#          num_of_reviews            category  \
# 2504391              78  Mexican restaurant
# 1422509              57          Restaurant
# 1460247              38         Coffee shop
# 1817065              38          Restaurant
# 2588766              38          Restaurant
#
#                                                    address
# 2504391  Juanito's Tacos, 1950 E Washington Blvd, Los A...
# 1422509    Eszett, 3510 Sunset Blvd, Los Angeles, CA 90026
# 1460247  Cafe De Mama, 1102 S Western Ave, Los Angeles,...
# 1817065  50/50 Juice Lounge, Where Health Meets Juice 4...
# 2588766  Mo's House Of Axe * Temporarily Closed *, 611 ...

# %%
# Probar la función con el DataFrame df_business
recomendaciones_zona = recomendar_restaurantes_por_zona(df_business, 'Pasadena', top_n=5, min_reviews=20)
recomendaciones_zona
# Out:
#                                           name  avg_rating  num_of_reviews  \
# 1672646                            Berry Opera         4.9              48
# 1672648                          Bodegón No.69         4.9              25
# 1589136  Pasadena Victory Park Farmer's Market         4.8              58
# 1093882                              HomeState         4.8              38
# 2427333                          Teddy's Tacos         4.8              37
#
#                                                   category  \
# 1672646                                             Bakery
# 1672648  Peruvian restaurant, Latin American restaurant...
# 1589136  Farmers' market, Food products supplier, Healt...
# 1093882                     Restaurant, Mexican restaurant
# 2427333                                         Restaurant
#
#                                                    address
# 1672646  Berry Opera, 811 Fair Oaks Ave, South Pasadena...
# 1672648  Bodegón No.69, 69 N Raymond Ave, Pasadena, CA ...
# 1589136  Pasadena Victory Park Farmer's Market, 2925 E ...
# 1093882    HomeState, 1992 Lincoln Ave, Pasadena, CA 91103
# 2427333  Teddy's Tacos, 1655 E Colorado Blvd, Pasadena,...

# %%
# Probar la función con el DataFrame df_business
recomendaciones_zona = recomendar_restaurantes_por_zona(df_business, 'Anaheim', top_n=5, min_reviews=20)
recomendaciones_zona
# Out:
#                  name  avg_rating  num_of_reviews  \
# 1785110   LIT Cafe OC         4.8              58
# 2477824  Atticus Cafe         4.8              58
# 152893      Nutrishop         4.8              37
# 1935239  Olligo Grill         4.7             137
# 1352824    Ceviche 19         4.7              54
#
#                                                   category  \
# 1785110                                  Brunch restaurant
# 2477824                               Breakfast restaurant
# 152893   Vitamin & supplements store, Health food store...
# 1935239                                         Restaurant
# 1352824                                Peruvian restaurant
#
#                                                    address
# 1785110  LIT Cafe OC, 1071 N Tustin Ave #100, Anaheim, ...
# 2477824  Atticus Cafe, 1304 S Magnolia Ave, Anaheim, CA...
# 152893   Nutrishop, 30 E Orangethorpe Ave #3, Anaheim, ...
# 1935239  Olligo Grill, 3240 Lincoln Ave, Anaheim, CA 92801
# 1352824  Ceviche 19, 1721 W Katella Ave G, Anaheim, CA ...

# %% [markdown]
# **Reformulamos función de búsqueda por palabras clave en reseñas**

# %%
def buscar_palabras_clave(df_unificado, palabras_clave, min_reviews=10):
    '''
    Esta función recibe un DataFrame y una lista de palabras clave.
    Busca las reseñas que tengan esas palabras clave, y las ordena según la puntuación ponderada.
    Devuelve una tabla con los locales mejor ponderados que respeten los criterios de búsqueda.
    '''
    # Unir las palabras clave en una expresión regular
    palabras_regex = '|'.join([f'\\b{palabra}\\b' for palabra in palabras_clave])
    
    # Filtrar las reseñas que contienen las palabras clave
    df_filtrado = df_unificado[df_unificado['text'].str.contains(palabras_regex, case=False, na=False)]
    
    if df_filtrado.empty:
        return "No se encontraron reseñas con las palabras clave."
    
    # Agrupar por gmap_id para evitar duplicados
    df_agrupado = df_filtrado.groupby('gmap_id').agg({
        'name': 'first',  # Mantener el primer nombre del restaurante
        'address': 'first',  # Mantener la primera dirección del restaurante
        'city': 'first',  # Mantener la primera ciudad
        'category': 'first',  # Mantener la primera categoría
        'avg_rating': 'mean',  # Promedio de la calificación
        'num_of_reviews': 'sum',  # Sumar el número total de reseñas
        'rating': 'mean',  # Promedio de las calificaciones de las reseñas
        'text': 'first'  # Mantener el primer texto de reseña
    }).reset_index()
    
    # Filtrar solo restaurantes con un mínimo de reseñas
    df_agrupado = df_agrupado[df_agrupado['num_of_reviews'] >= min_reviews]
    
    if df_agrupado.empty:
        return f"No se encontraron restaurantes con al menos {min_reviews} reseñas que contengan las palabras clave."
    
    # Ordenar por calificación promedio y número de reseñas
    df_top = df_agrupado.sort_values(['avg_rating', 'num_of_reviews'], ascending=[False, False])
    
    # Seleccionar las columnas relevantes para mostrar
    return df_top[['name', 'address', 'city', 'category', 'avg_rating', 'num_of_reviews', 'text']].head(10)

# %%
# Probar la función con df_unificado
palabras_clave = ['amazing', 'good', 'very good', 'friendly']
resultados_busqueda = buscar_palabras_clave(df_unificado, palabras_clave)
resultados_busqueda
# Out:
#                                name  \
# 5029     The Kilted Cake and Supply
# 267           LASO /Nepalese Fusion
# 5391                In-N-Out Burger
# 2568            North Fork Chai Co.
# 2518  FUKUMI RAMEN - Citrus Heights
# 4947              Gabino's Creperie
# 4715          San Diego Kabob Shack
# 5175    CALVIN'S KOREAN HOT CHICKEN
# 6346            Reverent Coffee Bar
# 4711      BAJA FISH TACOS & BURGERS
#
#                                                 address  \
# 5029  The Kilted Cake and Supply, 28061 Jefferson Av...
# 267   LASO /Nepalese Fusion, 101 Antonina Ave Suite ...
# 5391  In-N-Out Burger, 3483 Van Buren Boulevard, Riv...
# 2568  North Fork Chai Co., 661 Suite B, Newcastle Rd...
# 2518  FUKUMI RAMEN - Citrus Heights, 5410 Sunrise Bl...
# 4947  Gabino's Creperie, 170 E Palm Canyon Dr #4, Pa...
# 4715  San Diego Kabob Shack, 200 Broadway, Chula Vis...
# 5175  CALVIN'S KOREAN HOT CHICKEN, 3211 Holiday Ct S...
# 6346  Reverent Coffee Bar, 627 Deep Valley Dr Suite ...
# 4711  BAJA FISH TACOS & BURGERS, 71 Broadway, Chula ...
#
#                        city  \
# 5029               Temecula
# 267         American Canyon
# 5391              Riverside
# 2568              Newcastle
# 2518         Citrus Heights
# 4947           Palm Springs
# 4715            Chula Vista
# 5175               La Jolla
# 6346  Rolling Hills Estates
# 4711            Chula Vista
#
#                                                category  avg_rating  \
# 5029  Baking supply store, Airbrushing supply store,...         5.0
# 267                                   Fusion restaurant         5.0
# 5391  Hamburger restaurant, American restaurant, Din...         5.0
# 2568                                               Cafe         5.0
# 2518                                Japanese restaurant         5.0
# 4947                                         Restaurant         5.0
# 4715                                         Restaurant         5.0
# 5175  Fried chicken takeaway, Chicken shop, Chicken ...         5.0
# 6346                                        Coffee shop         5.0
# 4711               Seafood restaurant, Lunch restaurant         5.0
#
#       num_of_reviews                                               text
# 5029             240  So nice! Extremely organized. Amazing customer...
# 267              225  Wife and I had an excellent dinner at the outd...
# 5391             146  Very good service dine in or dine out its a gr...
# 2568             138  Great place to come to for some tra or coffee....
# 2518             100  So nice to have good ramen in the area! The po...
# 4947              96  I would start with saying this place is a hidd...
# 4715              94  We heard of San Diego Kabob Shack from the Eas...
# 5175              92  Wow. So very good. Also they have gluten free ...
# 6346              78  I've been here only a few times so far - which...
# 4711              76  I got the fish burrito and the ceviche.. don't...

# %%
# Probar la función con df_unificado
palabras_clave = ['good burger']
resultados_busqueda = buscar_palabras_clave(df_unificado, palabras_clave)
resultados_busqueda
# Out:
#                     name                                            address  \
# 44  Umai Savory Hot Dogs  Umai Savory Hot Dogs, 8443 Haven Ave #183, Ran...
# 20       In-N-Out Burger  In-N-Out Burger, 8010 N Blackstone Ave, Fresno...
# 32       In-N-Out Burger  In-N-Out Burger, 11880 Carmel Mountain Rd, Car...
# 10           Hidden Spot  Hidden Spot, 303 Grand Ave, South San Francisc...
# 1        In-N-Out Burger  In-N-Out Burger, 1275 Dana Dr, Redding, CA 960...
# 19       In-N-Out Burger  In-N-Out Burger, 4302 N Blackstone Ave, Fresno...
# 24       In-N-Out Burger  In-N-Out Burger, 1933 S Mooney Blvd, Visalia, ...
# 71       In-N-Out Burger  In-N-Out Burger, 600 S Brookhurst St, Anaheim,...
# 18       In-N-Out Burger  In-N-Out Burger, 3900 Pelandale Ave, Modesto, ...
# 66         Burger Lounge  Burger Lounge, 922 Orange Ave, Coronado, CA 92...
#
#                      city                                           category  \
# 44       Rancho Cucamonga  Hot dog restaurant, American restaurant, Chick...
# 20                 Fresno  Hamburger restaurant, American restaurant, Din...
# 32  Carmel Mountain Ranch  Hamburger restaurant, American restaurant, Din...
# 10    South San Francisco                               Hamburger restaurant
# 1                 Redding  Hamburger restaurant, American restaurant, Din...
# 19                 Fresno  Hamburger restaurant, American restaurant, Din...
# 24                Visalia  Hamburger restaurant, American restaurant, Din...
# 71                Anaheim  Hamburger restaurant, American restaurant, Din...
# 18                Modesto  Hamburger restaurant, American restaurant, Din...
# 66               Coronado          Hamburger restaurant, American restaurant
#
#     avg_rating  num_of_reviews  \
# 44         4.8             108
# 20         4.7            2408
# 32         4.7            1685
# 10         4.7              67
# 1          4.6           70952
# 19         4.6           14844
# 24         4.6           12234
# 71         4.6            7238
# 18         4.6            5337
# 66         4.6            4880
#
#                                                  text
# 44  My bf and I love a good burger. Umai has a pre...
# 20        Aways count on Good Burger and Great fries.
# 32                                        good burger
# 10     Just a really good burger.. I had the classic.
# 1   Good place to go for a good burger and fries a...
# 19               Good burger. Long wait in drive thru
# 24  AWESOME FOOD & EXPEDIENCY AFTER ORDERING. YOU ...
# 71  Great place for quick bites.Not to expect anyt...
# 18              Good burger and a very pleasant staff
# 66  Good burger, you can tell in the taste that ev...

# %%
# Probar la función con df_unificado
palabras_clave = ['excelent service']
resultados_busqueda = buscar_palabras_clave(df_unificado, palabras_clave)
resultados_busqueda
# Out:
#                                   name  \
# 7   Deliciosas Pupusas inside car wash
# 6    Saigon Dish Vietnamese Restaurant
# 9                       La Bella Pizza
# 5                 Las Lomas Restaurant
# 1           La Buena Taqueria and More
# 13                      Sabor A Malibu
# 14      Cool Hand Luke's - Santa Maria
# 8                            Tom's Jr.
# 12                             Denny's
# 10                     Jack in the Box
#
#                                               address         city  \
# 7   Deliciosas Pupusas inside car wash, 5509 Alham...  Los Angeles
# 6   Saigon Dish Vietnamese Restaurant, Spires Cour...     Lawndale
# 9   La Bella Pizza, 373 3rd Ave, Chula Vista, CA 9...  Chula Vista
# 5   Las Lomas Restaurant, 15677 Roxford St, Sylmar...       Sylmar
# 1   La Buena Taqueria and More, 1425 Main St, Wats...  Watsonville
# 13       Sabor A Malibu, 31242 CA-1, Malibu, CA 90265       Malibu
# 14  Cool Hand Luke's - Santa Maria, 1321 s, Nichol...  Santa Maria
# 8   Tom's Jr., 9856 Atlantic Ave, South Gate, CA 9...   South Gate
# 12  Denny's, 1440 W Pacific Coast Hwy, Wilmington,...   Wilmington
# 10  Jack in the Box, 1900 Mission Ave, Oceanside, ...    Oceanside
#
#                                              category  avg_rating  \
# 7                                          Restaurant         4.8
# 6   Vietnamese restaurant, Asian restaurant, Resta...         4.6
# 9   Italian restaurant, Banquet hall, Caterer, Tak...         4.4
# 5                                  Mexican restaurant         4.4
# 1   Fast food restaurant, Hamburger restaurant, Ho...         4.4
# 13                        Taco restaurant, Restaurant         4.4
# 14                   Steak house, American restaurant         4.3
# 8          Hamburger restaurant, Fast food restaurant         4.2
# 12   Diner, American restaurant, Breakfast restaurant         3.9
# 10  Fast food restaurant, Breakfast restaurant, Ch...         3.9
#
#     num_of_reviews                                               text
# 7               18              Excelent service and delicious food!!
# 6             1088  Best place for vietnamese soup. Excelent service.
# 9             2248  (Translated by Google) Excelent service\n\n(Or...
# 5              438  (Translated by Google) Excelent service\n\n(Or...
# 1              108  (Translated by Google) Excelent service\n\n(Or...
# 13              34  (Translated by Google) Excelent service\n\n(Or...
# 14             876                                   Excelent service
# 8             1324  (Translated by Google) Excelent service\n\n(Or...
# 12            1497  (Translated by Google) Excelent service\n\n(Or...
# 10             721  (Translated by Google) Excelent service\n\n(Or...

# %%
# Probar la función con df_unificado
palabras_clave = ['fresh seafood']
resultados_busqueda = buscar_palabras_clave(df_unificado, palabras_clave)
resultados_busqueda
# Out:
#                               name  \
# 6            O' by Claude Le Tohic
# 30                       Poki Roll
# 0   Princess Seafood Market & Deli
# 18    Ensenada's Surf N Turf Grill
# 10              Evangeline Cuisine
# 2                          Poke Go
# 34       Kikos Seafood Lunch Truck
# 29               Original Fish Co.
# 25           California Fish Grill
# 35                 Lure Fish House
#
#                                               address           city  \
# 6   O' by Claude Le Tohic, 165 O'Farrell St 5th Fl...  San Francisco
# 30  Poki Roll, 5721 Lincoln Ave c, Cypress, CA 906...        Cypress
# 0   Princess Seafood Market & Deli, 32410 N Harbor...     Fort Bragg
# 18  Ensenada's Surf N Turf Grill, 4749 Artesia Blv...       Lawndale
# 10  Evangeline Cuisine, 225 Cabrillo Hwy S #102 C,...  Half Moon Bay
# 2   Poke Go, 3555 Mt Diablo Blvd, Lafayette, CA 94549      Lafayette
# 34  Kikos Seafood Lunch Truck, 6090 Friars Rd, San...      San Diego
# 29  Original Fish Co., 11061 Los Alamitos Blvd, Lo...   Los Alamitos
# 25  California Fish Grill, 1530 Camino De La Reina...      San Diego
# 35  Lure Fish House, 3815 State St Suite G131, San...  Santa Barbara
#
#                                              category  avg_rating  \
# 6   Fine dining restaurant, French restaurant, Res...         4.9
# 30                                   Sushi restaurant         4.8
# 0                                  Seafood restaurant         4.7
# 18                     Seafood restaurant, Restaurant         4.7
# 10                    Seafood restaurant, Coffee shop         4.7
# 2                                          Restaurant         4.7
# 34                                 Seafood restaurant         4.7
# 29                                         Restaurant         4.6
# 25                                 Seafood restaurant         4.6
# 35                     Seafood restaurant, Restaurant         4.6
#
#     num_of_reviews                                               text
# 6               25  Swung in for dinner and my first concern was t...
# 30             266                            Nice and fresh seafood!
# 0             5180  Delicious fresh seafood in a bright and clean ...
# 18            2222  Fresh seafood, great customer service, very fr...
# 10             112  Amazing paella, one of the best I've had, and ...
# 2               68                                Great fresh seafood
# 34              54  I mean what can I say.....Everything is great ...
# 29            7518  Been coming here for about 30 years.  While I'...
# 25            4232  Lot of choice for fresh seafood for reasonable...
# 35            1088  This place is hit or miss on service. I’ve had...

# %% [markdown]
# **Reformulamos la función de recomendaciones en base a reseñas**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Esta función no se utiliza, ya que tenía algunos problemas:

# %%
def recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante, top_n=5):
    # Filtrar el DataFrame para encontrar el restaurante
    df_restaurante = df_unificado[df_unificado['name'].str.contains(nombre_restaurante, case=False, na=False)]
    
    if df_restaurante.empty:
        return f"No se encontraron restaurantes con el nombre {nombre_restaurante}."
    
    # Obtener el gmap_id del primer restaurante encontrado (asumiendo que es único)
    gmap_id = df_restaurante.iloc[0]['gmap_id']
    
    # Filtrar las reseñas que tienen texto y corresponden a este restaurante
    df_filtrado = df_unificado[(df_unificado['text'].notnull()) & (df_unificado['gmap_id'] == gmap_id)]
    
    if df_filtrado.empty:
        return f"No se encontraron reseñas para el restaurante {nombre_restaurante}."
    
    # Resetear el índice del DataFrame filtrado para evitar problemas con el índice
    df_filtrado = df_filtrado.reset_index(drop=True)
    
    # Crear la matriz TF-IDF
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(df_filtrado['text'])
    
    # Calcular la similitud del coseno entre todas las reseñas
    cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
    
    # Obtener el índice del restaurante en la matriz
    idx = 0  # Siempre usamos el primer índice ya que reiniciamos el DataFrame
    
    # Verificar que la matriz de similitud tiene el tamaño correcto
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Ordenar por similitud y devolver los más similares
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n + 1]
    
    # Obtener los índices de las reseñas recomendadas
    review_indices = [i[0] for i in sim_scores]
    
    # Obtener información del restaurante para las reseñas recomendadas
    df_recomendaciones = df_unificado[df_unificado['gmap_id'] == gmap_id].drop_duplicates(subset='gmap_id')
    
    # Devolver la información de los restaurantes recomendados junto con las reseñas
    recomendaciones = df_recomendaciones[['name', 'address', 'city', 'category', 'avg_rating', 'num_of_reviews']].reset_index(drop=True)
    
    # Asegurarse de que la longitud de reseñas coincida con la de recomendaciones
    if len(recomendaciones) > 0:
        # Reasignar las reseñas si hay al menos una recomendación
        recomendaciones['reseñas'] = [''] * len(recomendaciones)
        for idx, review_index in enumerate(review_indices):
            if idx < len(recomendaciones):
                recomendaciones.at[idx, 'reseñas'] = df_filtrado.iloc[review_index]['text']
    
    return recomendaciones

# %%
# Probar la función con df_unificado
nombre_restaurante = 'Pizza Hut'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#         name                                            address      city  \
# 0  Pizza Hut  Pizza Hut, 7750 El Camino Real suite e, Carlsb...  Carlsbad
#
#                                             category  avg_rating  \
# 0  Pizza restaurant, Chicken wings restaurant, De...         3.6
#
#    num_of_reviews reseñas
# 0              28    Good

# %%
# Probar la función con df_unificado
nombre_restaurante = 'Starbucks'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#         name                                            address     city  \
# 0  Starbucks  Starbucks, Newport FS Town Center, Menifee, CA...  Menifee
#
#       category  avg_rating  num_of_reviews  \
# 0  Coffee shop         4.5              26
#
#                                              reseñas
# 0  Finally a drive thru that's close to the house...

# %%
# Probar la función con df_unificado
nombre_restaurante = 'Burger King'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#           name                                            address  \
# 0  Burger King  Burger King, 3030 Plaza Bonita Rd Suite 2075, ...
#
#             city              category  avg_rating  num_of_reviews reseñas
# 0  National City  Fast food restaurant         2.5              15

# %% [markdown]
# Con el enfoque que se le dió a esta función, se buscan reseñas relacionadas con un restaurante y luego utiliza esas reseñas para recomendar el mismo restaurante. De esa forma, decidimos cambiar el enfoque para que efectivamente esta recomendación sea de utilidad.

# %%
# Probar la función con df_unificado
nombre_restaurante = 'Pizza Hut'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#                        name  \
# 0                 JiST cafe
# 1        Yashima Restaurant
# 2                 SUSHI YAN
# 3           In-N-Out Burger
# 4  La Ranchera Mexican Food
#
#                                              address         city  \
# 0  JiST cafe, 116 Judge John Aiso St, Los Angeles...  Los Angeles
# 1  Yashima Restaurant, 236 E Rowland St, Covina, ...       Covina
# 2   SUSHI YAN, 9047 Central Ave, Montclair, CA 91763    Montclair
# 3  In-N-Out Burger, 600 S Brookhurst St, Anaheim,...      Anaheim
# 4  La Ranchera Mexican Food, 911 E La Habra Blvd,...     La Habra
#
#                                             category  avg_rating  \
# 0                      Cafe, New American restaurant         4.4
# 1                    Japanese restaurant, Restaurant         4.7
# 2                                   Sushi restaurant         4.4
# 3  Hamburger restaurant, American restaurant, Din...         4.6
# 4      Mexican restaurant, Latin American restaurant         4.1
#
#    num_of_reviews                                               text
# 0             448  Don't be a hater is place is great! I can't st...
# 1             178  WHAT IT IS\nSushi restaurant and bar. They als...
# 2              56  So I saw the reviews and decided to give this ...
# 3            3619  I mean, in n out, is in n out. The burgers are...
# 4             177  My review is based on delivery. I’ve never bee...

# %%
# Probar la función con df_unificado
nombre_restaurante = 'Starbucks'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#                                   name  \
# 0                            Starbucks
# 1                            Starbucks
# 2                            Pizza Man
# 3  Friends With Benedicts Mimosa House
#
#                                              address             city  \
# 0  Starbucks, Newport FS Town Center, Menifee, CA...          Menifee
# 1  Starbucks, 11697 Del Amo Blvd, Lakewood, CA 90...         Lakewood
# 2  Pizza Man, 10940 W Magnolia Blvd, North Hollyw...  North Hollywood
# 3  Friends With Benedicts Mimosa House, Palladio ...           Folsom
#
#                                             category  avg_rating  \
# 0                                        Coffee shop         4.5
# 1  Coffee shop, Breakfast restaurant, Cafe, Coffe...         4.2
# 2                   Pizza restaurant, Pizza delivery         3.9
# 3                               Breakfast restaurant         3.9
#
#    num_of_reviews                                               text
# 0              26  I love the new location!  They were originally...
# 1             285  Q)  Did you attend the Grand Opening of this S...
# 2             167  2019.01-03: Can't wait for my order! It's been...
# 3              18  Found this new location on our way out from sh...

# %% [markdown]
# En las primeras pruebas, observamos que si bien se sigue un patrón de similitud para la recomendación, se aleja demasiado de la categoría. Hay más coincidencia, por ejemplo, cuando buscamos cafeterías. Para mejorar esta cuestión, debemos contemplar la categoría como otro factor. Agregaremos una columna combinada que tenga las palabras de la columna 'category' (varias veces para darle más preponderancia) y 'text', y la búsqueda de coincidencias se haga a partir de esa nueva columna.

# %%
# Crear una columna combinada 'category_text' con la categoría repetida 3 veces para darle mayor peso
df_unificado['category_text'] = df_unificado['category'] + ' ' + df_unificado['category'] + ' ' + df_unificado['category'] + ' ' + df_unificado['text']

# %% [markdown]
# ## Sistema final de recomendación en base a reseñas

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante, top_n=5):
    # Filtrar el DataFrame para encontrar el restaurante
    df_restaurante = df_unificado[df_unificado['name'].str.contains(nombre_restaurante, case=False, na=False)]
    
    if df_restaurante.empty:
        return f"No se encontraron restaurantes con el nombre {nombre_restaurante}."
    
    # Obtener el gmap_id del restaurante
    gmap_id_restaurante = df_restaurante.iloc[0]['gmap_id']
    
    # Filtrar las reseñas que tienen texto y corresponden a este restaurante
    df_reseñas_restaurante = df_unificado[(df_unificado['text'].notnull()) & (df_unificado['gmap_id'] == gmap_id_restaurante)]
    
    if df_reseñas_restaurante.empty:
        return f"No se encontraron reseñas para el restaurante {nombre_restaurante}."
    
    # Crear la matriz TF-IDF para las reseñas combinadas
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix_reseñas = tfidf.fit_transform(df_reseñas_restaurante['category_text'])
    tfidf_matrix_todas_reseñas = tfidf.transform(df_unificado['category_text'])
    
    # Calcular la similitud del coseno entre las reseñas del restaurante y todas las reseñas
    cosine_sim = cosine_similarity(tfidf_matrix_reseñas, tfidf_matrix_todas_reseñas)
    
    # Obtener el índice de reseñas más similares
    sim_scores = list(enumerate(cosine_sim.mean(axis=0)))  # Usar la media de similitud para comparar con todas las reseñas
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[:top_n]
    
    # Obtener los índices de los restaurantes recomendados
    restaurant_indices = [i[0] for i in sim_scores]
    
    # Asegurarse de que los índices están dentro del rango del DataFrame
    if restaurant_indices:
        # Obtener información de los restaurantes recomendados
        recomendaciones = df_unificado.iloc[restaurant_indices].drop_duplicates(subset='gmap_id')
        recomendaciones = recomendaciones[['name', 'address', 'city', 'category', 'avg_rating', 'num_of_reviews', 'text']].reset_index(drop=True)
    else:
        recomendaciones = pd.DataFrame()  # Devolver un DataFrame vacío si no hay recomendaciones
    
    return recomendaciones

# %%
nombre_restaurante = 'Vons Chicken'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#                                      name  \
# 0                   Crab House at Pier 39
# 1                            Vons Chicken
# 2  Hong Kong Flower Lounge Restaurant 香滿樓
# 3                                Tom's Jr
# 4                        Olympian Burgers
#
#                                              address           city  \
# 0  Crab House at Pier 39, San Francisco, 203 Pier...  San Francisco
# 1  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...      La Mirada
# 2  Hong Kong Flower Lounge Restaurant 香滿樓, 51 E M...       Millbrae
# 3  Tom's Jr, 1725 N Long Beach Blvd, Compton, CA ...        Compton
# 4  Olympian Burgers, 2701 S Vermont Ave, Los Ange...    Los Angeles
#
#                                             category  avg_rating  \
# 0  Crab house, American restaurant, Bar, Californ...         4.2
# 1                                         Restaurant         4.5
# 2  Chinese restaurant, Dim sum restaurant, Seafoo...         3.9
# 3  Hamburger restaurant, Fast food restaurant, Re...         4.4
# 4  Family restaurant, American restaurant, Fast f...         4.5
#
#    num_of_reviews                                               text
# 0            2068  (Translated by Google) It has a different expe...
# 1              18  (Translated by Google) There is a different me...
# 2             918  (Translated by Google) The taste is good.\n\nH...
# 3            1248  (Translated by Google) I love buying the famil...
# 4            1500  (Translated by Google) A place with many years...

# %%
nombre_restaurante = 'Pizza Hut'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#         name                                            address          city  \
# 0  Pizza Hut  Pizza Hut, 7750 El Camino Real suite e, Carlsb...      Carlsbad
# 1  Pizza Hut  Pizza Hut, 8947 W Pico Blvd, Los Angeles, CA 9...   Los Angeles
# 2  Pizza Hut  Pizza Hut, 415 E Avenida Pico Ste K, San Cleme...  San Clemente
# 3  Pizza Hut       Pizza Hut, 92 W Court St, Woodland, CA 95695      Woodland
#
#                                             category  avg_rating  \
# 0  Pizza restaurant, Chicken wings restaurant, De...         3.6
# 1  Pizza restaurant, Chicken wings restaurant, De...         3.0
# 2  Pizza restaurant, Chicken wings restaurant, De...         2.9
# 3  Pizza restaurant, Chicken wings restaurant, De...         3.7
#
#    num_of_reviews                               text
# 0              28                               Good
# 1              48                          It's okay
# 2              38  I love this place...greatest ever
# 3              38                        I loved it😁

# %%
nombre_restaurante = 'Starbucks'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#         name                                            address        city  \
# 0  Starbucks  Starbucks, Newport FS Town Center, Menifee, CA...     Menifee
# 1  Starbucks  Starbucks, 11697 Del Amo Blvd, Lakewood, CA 90...    Lakewood
# 2  Starbucks       Starbucks, 78752 CA-111, La Quinta, CA 92253   La Quinta
# 3  Starbucks  Starbucks, 4110 Norwood Ave, Sacramento, CA 95...  Sacramento
#
#                                             category  avg_rating  \
# 0                                        Coffee shop         4.5
# 1  Coffee shop, Breakfast restaurant, Cafe, Coffe...         4.2
# 2                                  Coffee shop, Cafe         3.9
# 3  Coffee shop, Breakfast restaurant, Cafe, Coffe...         4.0
#
#    num_of_reviews                                               text
# 0              26  Finally a drive thru that's close to the house...
# 1             285  Q)  Did you attend the Grand Opening of this S...
# 2              47        New location in Palm Desert.  Good location
# 3             955  Some staff are wonderful. Location is main dra...

# %%
nombre_restaurante = 'Subway'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#      name                                            address          city  \
# 0  Subway  Subway, 124 Lomas Santa Fe Dr Suite 101, Solan...  Solana Beach
# 1  Subway  Subway, 2138 Hilltop Mall Rd Kiosk K127, Richm...      Richmond
# 2  Subway  Subway, 11123 Long Beach Blvd Unit 10, Lynwood...       Lynwood
# 3  Subway  Subway, 83097 Avenue 48 # D1a, Coachella, CA 9...     Coachella
#
#                                             category  avg_rating  \
# 0  Sandwich shop, Caterer, Fast food restaurant, ...         3.5
# 1  Sandwich shop, Fast food restaurant, Takeout R...         3.7
# 2  Sandwich shop, Caterer, Fast food restaurant, ...         3.8
# 3  Sandwich shop, Caterer, Fast food restaurant, ...         3.5
#
#    num_of_reviews                                               text
# 0              58  Poor customer service. First the employee trie...
# 1              49  This location is good! The Subs were once alwa...
# 2             103                             I liked this location.
# 3              58                                 Love this location

# %%
nombre_restaurante = '21 Biryani Pots'
resultados_recomendaciones = recomendar_restaurantes_por_reseñas(df_unificado, nombre_restaurante)
resultados_recomendaciones
# Out:
#                       name                                            address  \
# 0  Paradise Biryani Pointe  Paradise Biryani Pointe, 8995 Mira Mesa Blvd S...
# 1                   Sakoon  Sakoon, 357 Castro St, Mountain View, CA 94041...
# 2            Biryani House     Biryani House, 949 Ruff Dr, San Jose, CA 95110
#
#             city                                           category  \
# 0      San Diego                                  Indian restaurant
# 1  Mountain View                             Indian restaurant, Bar
# 2       San Jose  Indian takeaway, Biryani restaurant, Indian re...
#
#    avg_rating  num_of_reviews  \
# 0         3.5             618
# 1         4.2            2474
# 2         4.7              68
#
#                                                 text
# 0  Authentic biryani place. Their biryani is very...
# 1  Very Authentic Indian food.\nHappy Hour for dr...
# 2  Incredible place that deserves more ratings an...

# %% [markdown]
# Este sistema funciona mejor con pequeños negocios que con grandes cadenas, porque cada sucursal de las cadenas (al tratarse de franquicias), comparten reseñas similares. Como puede verse, un pequeño local de comida India me trae restaurantes o locales similares del Estado de California.
